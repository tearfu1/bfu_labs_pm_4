# %% [markdown]
# подготовительные дейтсвия

# %%
import sys, os
import graphviz

transition_probs = {
    's0': {
        'a0': {'s0': 0.5, 's2': 0.5},
        'a1': {'s2': 1}
    },
    's1': {
        'a0': {'s0': 0.7, 's1': 0.1, 's2': 0.2},
        'a1': {'s1': 0.95, 's2': 0.05}
    },
    's2': {
        'a0': {'s0': 0.4, 's2': 0.6},
        'a1': {'s0': 0.3, 's1': 0.3, 's2': 0.4}
    }
}

rewards = {
    's1': {'a0': {'s0': +5}},
    's2': {'a1': {'s0': -1}}
}

from mdp import MDP
mdp = MDP(transition_probs, rewards, initial_state='s0')
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
print('начальное состояние:', mdp.reset())
next_state, reward, done, info = mdp.step('a1')
print(f'next_state = {next_state}, reward = {reward}, done = {done}')
# Out:
# начальное состояние: s0
# next_state = s2, reward = 0.0, done = False

# %%
print("все состояния:", mdp.get_all_states())
print("действия из s1:", mdp.get_possible_actions('s1'))
print("переходы s1->a0:", mdp.get_next_states('s1', 'a0'))
print("награда s1,a0->s0:", mdp.get_reward('s1', 'a0', 's0'))
print("вероятность s1,a0->s0:", mdp.get_transition_prob('s1', 'a0', 's0'))
# Out:
# все состояния: ('s0', 's1', 's2')
# действия из s1: ('a0', 'a1')
# переходы s1->a0: {'s0': 0.7, 's1': 0.1, 's2': 0.2}
# награда s1,a0->s0: 5
# вероятность s1,a0->s0: 0.7

# %% [markdown]
# визуализация графа

# %%
from mdp import has_graphviz
from IPython.display import display

print("Graphviz available:", has_graphviz)
if has_graphviz:
    from mdp import plot_graph, plot_graph_with_state_values, plot_graph_optimal_strategy_and_state_values
    display(plot_graph(mdp))
# Out:
# Graphviz available: True
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %% [markdown]
# итерации по значениям

# %%
def get_action_value(mdp, state_values, state, action, gamma):
    """ Вычисляет Q(s, a) по формуле Беллмана """
    q_val = 0
    for next_s, prob in mdp.get_next_states(state, action).items():
        r = mdp.get_reward(state, action, next_s)
        q_val += prob * (r + gamma * state_values[next_s])
    return q_val

# %%
import numpy as np
test_Vs = {s: i for i, s in enumerate(sorted(mdp.get_all_states()))}
assert np.isclose(get_action_value(mdp, test_Vs, 's2', 'a1', 0.9), 0.69)
assert np.isclose(get_action_value(mdp, test_Vs, 's1', 'a0', 0.9), 3.95)

# %%
def get_new_state_value(mdp, state_values, state, gamma):
    """ Возвращает обновлённое значение V(s) = max_a Q(s,a) """
    if mdp.is_terminal(state):
        return 0

    actions = mdp.get_possible_actions(state)
    q_values = [get_action_value(mdp, state_values, state, a, gamma) for a in actions]
    return max(q_values)

# %%
gamma = 0.9
num_iter = 100
min_difference = 0.001

# начальные значения V(s) = 0
state_values = {s: 0 for s in mdp.get_all_states()}

if has_graphviz:
    display(plot_graph_with_state_values(mdp, state_values))

for i in range(num_iter):
    new_state_values = {
        s: get_new_state_value(mdp, state_values, s, gamma)
        for s in mdp.get_all_states()
    }
    assert isinstance(new_state_values, dict)

    diff = max(abs(new_state_values[s] - state_values[s]) for s in mdp.get_all_states())

    print(f"iter {i:4d} | diff: {diff:6.5f} | ", end="")
    print(' '.join(f"V({s}) = {v:.3f}" for s, v in state_values.items()))

    state_values = new_state_values

    if diff < min_difference:
        print("Terminated")
        break
# Out:
# iter    0 | diff: 3.50000 | V(s0) = 0.000 V(s1) = 0.000 V(s2) = 0.000
# iter    1 | diff: 0.64500 | V(s0) = 0.000 V(s1) = 3.500 V(s2) = 0.000
# iter    2 | diff: 0.58050 | V(s0) = 0.000 V(s1) = 3.815 V(s2) = 0.645
# iter    3 | diff: 0.43582 | V(s0) = 0.581 V(s1) = 3.959 V(s2) = 0.962
# iter    4 | diff: 0.30634 | V(s0) = 0.866 V(s1) = 4.395 V(s2) = 1.272
# iter    5 | diff: 0.27571 | V(s0) = 1.145 V(s1) = 4.670 V(s2) = 1.579
# iter    6 | diff: 0.24347 | V(s0) = 1.421 V(s1) = 4.926 V(s2) = 1.838
# iter    7 | diff: 0.21419 | V(s0) = 1.655 V(s1) = 5.169 V(s2) = 2.075
# iter    8 | diff: 0.19277 | V(s0) = 1.868 V(s1) = 5.381 V(s2) = 2.290
# iter    9 | diff: 0.17327 | V(s0) = 2.061 V(s1) = 5.573 V(s2) = 2.481
# iter   10 | diff: 0.15569 | V(s0) = 2.233 V(s1) = 5.746 V(s2) = 2.654
# iter   11 | diff: 0.14012 | V(s0) = 2.389 V(s1) = 5.902 V(s2) = 2.810
# iter   12 | diff: 0.12610 | V(s0) = 2.529 V(s1) = 6.042 V(s2) = 2.950
# ...

# %%
assert abs(state_values['s0'] - 3.781) < 0.01
assert abs(state_values['s1'] - 7.294) < 0.01
assert abs(state_values['s2'] - 4.202) < 0.01

# %%
def get_optimal_action(mdp, state_values, state, gamma=0.9):
    """ Находит оптимальное действие как argmax Q(s, a) """
    if mdp.is_terminal(state):
        return None

    actions = mdp.get_possible_actions(state)
    return max(actions, key=lambda a: get_action_value(mdp, state_values, state, a, gamma))

# %%
assert get_optimal_action(mdp, state_values, 's0', gamma) == 'a1'
assert get_optimal_action(mdp, state_values, 's1', gamma) == 'a0'
assert get_optimal_action(mdp, state_values, 's2', gamma) == 'a1'
assert get_optimal_action(mdp, {'s0': -1e10, 's1': 0, 's2': -2e10}, 's0', 0.9) == 'a0', \
"Убедитесь, что вы правильно обрабатываете отрицательные значения Q произвольной величины."
assert get_optimal_action(mdp, {'s0': -2e10, 's1': 0, 's2': -1e10}, 's0', 0.9) == 'a1', \
"Убедитесь, что вы правильно обрабатываете отрицательные значения Q произвольной величины."

# %%
# проверка средней награды оптимальной стратегии
s = mdp.reset()
rewards = []
for _ in range(10000):
    s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
    rewards.append(r)

avg_reward = np.mean(rewards)
print(f"average reward: {avg_reward}")
assert(0.40 < avg_reward < 0.55)
# Out:
# average reward: 0.4382

# %% [markdown]
# Среда Frozen lake

# %%
#Frozen Lake Env
from mdp import FrozenLakeEnv
mdp = FrozenLakeEnv(slip_chance=0)
mdp.render()
# Out:
# *FFF
# FHFH
# FFFH
# HFFG

# %%
def value_iteration(mdp, state_values=None, gamma=0.9, num_iter=1000, min_difference=1e-5):
    """ Итерация по значениям до сходимости """
    if state_values is None:
        state_values = {s: 0 for s in mdp.get_all_states()}

    for i in range(num_iter):
        new_state_values = {
            s: get_new_state_value(mdp, state_values, s, gamma)
            for s in mdp.get_all_states()
        }
        assert isinstance(new_state_values, dict)

        diff = max(abs(new_state_values[s] - state_values[s]) for s in mdp.get_all_states())
        print(f"iter {i:4d} | diff: {diff:.6f} | V(start): {new_state_values[mdp._initial_state]:.3f}")

        state_values = new_state_values
        if diff < min_difference:
            break

    return state_values

# %%
state_values = value_iteration(mdp)
s = mdp.reset()
mdp.render()
for t in range(100):
    a = get_optimal_action(mdp, state_values, s, gamma)
    print(a, end='\n\n')
    s, r, done, _ = mdp.step(a)
    mdp.render()
    if done:
        break
# Out:
# iter    0 | diff: 1.000000 | V(start): 0.000
# iter    1 | diff: 0.900000 | V(start): 0.000
# iter    2 | diff: 0.810000 | V(start): 0.000
# iter    3 | diff: 0.729000 | V(start): 0.000
# iter    4 | diff: 0.656100 | V(start): 0.000
# iter    5 | diff: 0.590490 | V(start): 0.590
# iter    6 | diff: 0.000000 | V(start): 0.590
# *FFF
# FHFH
# FFFH
# HFFG
#
# down
#
# SFFF
# *HFH
# FFFH
# HFFG
#
# down
#
# SFFF
# FHFH
# *FFH
# HFFG
#
# right
#
# SFFF
# FHFH
# F*FH
# HFFG
#
# down
#
# SFFF
# FHFH
# FFFH
# H*FG
#
# right
#
# SFFF
# FHFH
# FFFH
# HF*G
#
# right
#
# SFFF
# FHFH
# FFFH
# HFF*

# %%
import matplotlib.pyplot as plt

def draw_policy(mdp, state_values, gamma=0.9):
    plt.figure(figsize=(3, 3))
    h, w = mdp.desc.shape
    all_states = sorted(mdp.get_all_states())

    V = np.array([state_values[s] for s in all_states])
    Pi = {s: get_optimal_action(mdp, state_values, s, gamma) for s in all_states}

    plt.imshow(V.reshape(h, w), cmap='gray', interpolation='none', clim=(0, 1))

    ax = plt.gca()
    ax.set_xticks(np.arange(w + 1) - 0.5)
    ax.set_yticks(np.arange(h + 1) - 0.5)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    ax.grid(True, color='b', lw=2, ls='-')

    arrow_map = {'left': (-1, 0), 'down': (0, -1), 'right': (1, 0), 'up': (0, 1)}

    for y in range(h):
        for x in range(w):
            cell = str(mdp.desc[y, x].item())
            plt.text(x, y, cell, color='g', size=12, va='center', ha='center', fontweight='bold')
            act = Pi.get((y, x))
            if act is not None:
                dx, dy = arrow_map[act]
                plt.arrow(x, y, dx * 0.4, -dy * 0.4,
                          color='red', head_width=0.2, head_length=0.2, linewidth=2)
    plt.show()

# %%
state_values = {s: 0 for s in mdp.get_all_states()}
for i in range(10):
    print("after iteration %i" % i)
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
# please ignore iter 0 at each step
# Out:
# after iteration 0
# iter    0 | diff: 1.000000 | V(start): 0.000
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# after iteration 1
# iter    0 | diff: 0.900000 | V(start): 0.000
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# after iteration 2
# iter    0 | diff: 0.810000 | V(start): 0.000
# ...

# %%
from IPython.display import clear_output
from time import sleep

mdp = FrozenLakeEnv(map_name='8x8', slip_chance=0.1)
state_values = {s: 0 for s in mdp.get_all_states()}

for i in range(30):
    clear_output(True)
    print(f"итерация {i}")
    state_values = value_iteration(mdp, state_values, num_iter=1)
    draw_policy(mdp, state_values)
    sleep(0.5)
# Out:
# итерация 29
# iter    0 | diff: 0.000000 | V(start): 0.198
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
mdp = FrozenLakeEnv(slip_chance=0)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    game_reward = 0
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        game_reward += r
        if done:
            break
    total_rewards.append(game_reward)

print(f"average reward: {np.mean(total_rewards)}")
assert(1.0 <= np.mean(total_rewards) <= 1.0)
print("Well done!")
# Out:
# iter    0 | diff: 1.000000 | V(start): 0.000
# iter    1 | diff: 0.900000 | V(start): 0.000
# iter    2 | diff: 0.810000 | V(start): 0.000
# iter    3 | diff: 0.729000 | V(start): 0.000
# iter    4 | diff: 0.656100 | V(start): 0.000
# iter    5 | diff: 0.590490 | V(start): 0.590
# iter    6 | diff: 0.000000 | V(start): 0.590
# average reward: 1.0
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.1)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    game_reward = 0
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        game_reward += r
        if done:
            break
    total_rewards.append(game_reward)

print(f"average reward: {np.mean(total_rewards)}")
assert(0.8 <= np.mean(total_rewards) <= 0.95)
print("Well done!")
# Out:
# iter    0 | diff: 0.900000 | V(start): 0.000
# iter    1 | diff: 0.729000 | V(start): 0.000
# iter    2 | diff: 0.623295 | V(start): 0.000
# iter    3 | diff: 0.504869 | V(start): 0.000
# iter    4 | diff: 0.408944 | V(start): 0.000
# iter    5 | diff: 0.348678 | V(start): 0.349
# iter    6 | diff: 0.065290 | V(start): 0.410
# iter    7 | diff: 0.058322 | V(start): 0.468
# iter    8 | diff: 0.011394 | V(start): 0.480
# iter    9 | diff: 0.007637 | V(start): 0.487
# iter   10 | diff: 0.001641 | V(start): 0.489
# iter   11 | diff: 0.000937 | V(start): 0.490
# iter   12 | diff: 0.000218 | V(start): 0.490
# iter   13 | diff: 0.000113 | V(start): 0.490
# iter   14 | diff: 0.000028 | V(start): 0.490
# iter   15 | diff: 0.000014 | V(start): 0.490
# iter   16 | diff: 0.000004 | V(start): 0.490
# average reward: 0.886
# Well done!

# %%
mdp = FrozenLakeEnv(slip_chance=0.25)
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    game_reward = 0
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        game_reward += r
        if done:
            break
    total_rewards.append(game_reward)

print(f"average reward: {np.mean(total_rewards)}")
assert(0.6 <= np.mean(total_rewards) <= 0.7)
print("Well done!")
# Out:
# iter    0 | diff: 0.750000 | V(start): 0.000
# iter    1 | diff: 0.506250 | V(start): 0.000
# iter    2 | diff: 0.398672 | V(start): 0.000
# iter    3 | diff: 0.269104 | V(start): 0.000
# iter    4 | diff: 0.181645 | V(start): 0.000
# iter    5 | diff: 0.140126 | V(start): 0.140
# iter    6 | diff: 0.070282 | V(start): 0.199
# iter    7 | diff: 0.060298 | V(start): 0.260
# iter    8 | diff: 0.025937 | V(start): 0.285
# iter    9 | diff: 0.019180 | V(start): 0.305
# iter   10 | diff: 0.008580 | V(start): 0.313
# iter   11 | diff: 0.005596 | V(start): 0.319
# iter   12 | diff: 0.002598 | V(start): 0.321
# iter   13 | diff: 0.001586 | V(start): 0.323
# iter   14 | diff: 0.000760 | V(start): 0.324
# iter   15 | diff: 0.000445 | V(start): 0.324
# iter   16 | diff: 0.000219 | V(start): 0.324
# iter   17 | diff: 0.000125 | V(start): 0.325
# iter   18 | diff: 0.000062 | V(start): 0.325
# iter   19 | diff: 0.000035 | V(start): 0.325
# iter   20 | diff: 0.000018 | V(start): 0.325
# ...

# %%
mdp = FrozenLakeEnv(slip_chance=0.2, map_name='8x8')
state_values = value_iteration(mdp)

total_rewards = []
for game_i in range(1000):
    s = mdp.reset()
    game_reward = 0
    for t in range(100):
        s, r, done, _ = mdp.step(get_optimal_action(mdp, state_values, s, gamma))
        game_reward += r
        if done:
            break
    total_rewards.append(game_reward)

print(f"average reward: {np.mean(total_rewards)}")
assert(0.6 <= np.mean(total_rewards) <= 0.8)
print("Well done!")
# Out:
# iter    0 | diff: 0.800000 | V(start): 0.000
# iter    1 | diff: 0.576000 | V(start): 0.000
# iter    2 | diff: 0.414720 | V(start): 0.000
# iter    3 | diff: 0.298598 | V(start): 0.000
# iter    4 | diff: 0.241865 | V(start): 0.000
# iter    5 | diff: 0.193492 | V(start): 0.000
# iter    6 | diff: 0.153245 | V(start): 0.000
# iter    7 | diff: 0.122875 | V(start): 0.000
# iter    8 | diff: 0.099303 | V(start): 0.000
# iter    9 | diff: 0.080375 | V(start): 0.000
# iter   10 | diff: 0.064261 | V(start): 0.000
# iter   11 | diff: 0.051290 | V(start): 0.000
# iter   12 | diff: 0.043304 | V(start): 0.000
# iter   13 | diff: 0.038023 | V(start): 0.033
# iter   14 | diff: 0.033316 | V(start): 0.058
# iter   15 | diff: 0.029095 | V(start): 0.087
# iter   16 | diff: 0.018554 | V(start): 0.106
# iter   17 | diff: 0.014032 | V(start): 0.120
# iter   18 | diff: 0.008097 | V(start): 0.128
# iter   19 | diff: 0.005551 | V(start): 0.133
# iter   20 | diff: 0.003208 | V(start): 0.137
# ...
